# %% [markdown]
# # TODO: Title
#
# This notebook lists all the steps that you need to complete the complete this project. You will need to complete all the TODOs in this notebook as well as in the README and the two python scripts included with the starter code.
#
#
# **TODO**: Give a helpful introduction to what this notebook is for. Remember that comments, explanations and good documentation make your project informative and professional.
#
# **Note:** This notebook has a bunch of code and markdown cells with TODOs that you have to complete. These are meant to be helpful guidelines for you to finish your project while meeting the requirements in the project rubrics. Feel free to change the order of these the TODO's and use more than one TODO code cell to do all your tasks.

# %%
# TODO: Install any packages that you might need
# For instance, you will need the smdebug package
# !pip install smdebug

# %%
# TODO: Import any packages that you might need
# For instance you will need Boto3 and Sagemaker
import sagemaker
import boto3
from sagemaker import get_execution_role
from sagemaker import session

# %%
bucket= "sagemaker-studio-g0o8pxe34gt"
print("Default Bucket : {}".format(bucket))

region = "us-east-2"
print("AWS Region: {}".format(region))

role = get_execution_role()
print("RoleArn: {}".format(role))
# Out:
# Default Bucket : sagemaker-studio-g0o8pxe34gt
# AWS Region: us-east-2
# RoleArn: arn:aws:iam::461971093615:role/service-role/AmazonSageMakerServiceCatalogProductsUseRole

# %%
import os 

os.environ["DEFAULT_S3_BUCKET"] = bucket
# !aws s3 sync ./doImages s3://${DEFAULT_S3_BUCKET}/dogImages/

# %%
# !aws s3 ls s3://sagemaker-studio-g0o8pxe34gt/dogImages/train/ --recursive --summarize | grep "Total Objects:"
# Out:
# Total Objects: 6681

# %%
# !aws s3 ls s3://sagemaker-studio-g0o8pxe34gt/dogImages/test/ --recursive --summarize | grep "Total Objects:"
# Out:
# Total Objects: 837

# %%
# !aws s3 ls s3://sagemaker-studio-g0o8pxe34gt/dogImages/valid/ --recursive --summarize | grep "Total Objects:"
# Out:
# Total Objects: 836

# %%
import matplotlib.pyplot as plt
plt.imshow(plt.imread('dogImages/train/003.Airedale_terrier/Airedale_terrier_00157.jpg'));

# %%
#Number of train images
import os
folders_path = 'dogImages/train/'
totalFiles = 0
totalDir = 0
for base, dirs, files in os.walk(folders_path):
    print('Searching in : ',base)
    for directories in dirs:
        totalDir += 1
    for Files in files:
        totalFiles += 1

print('Total number of train images',totalFiles)
print('Total Number of classes',totalDir)
# Out:
# Searching in :  dogImages/train/
# Searching in :  dogImages/train/027.Bloodhound
# Searching in :  dogImages/train/072.German_shorthaired_pointer
# Searching in :  dogImages/train/047.Chesapeake_bay_retriever
# Searching in :  dogImages/train/102.Manchester_terrier
# Searching in :  dogImages/train/070.German_pinscher
# Searching in :  dogImages/train/094.Komondor
# Searching in :  dogImages/train/025.Black_and_tan_coonhound
# Searching in :  dogImages/train/062.English_setter
# Searching in :  dogImages/train/035.Boykin_spaniel
# Searching in :  dogImages/train/087.Irish_terrier
# Searching in :  dogImages/train/024.Bichon_frise
# Searching in :  dogImages/train/017.Bearded_collie
# Searching in :  dogImages/train/112.Nova_scotia_duck_tolling_retriever
# Searching in :  dogImages/train/122.Pointer
# Searching in :  dogImages/train/018.Beauceron
# Searching in :  dogImages/train/085.Irish_red_and_white_setter
# Searching in :  dogImages/train/021.Belgian_sheepdog
# ...

# %%
#Number of test images 
import os
folders_path = 'dogImages/test/'
totalFiles = 0
totalDir = 0
for base, dirs, files in os.walk(folders_path):
    print('Searching in : ',base)
    for directories in dirs:
        totalDir += 1
    for Files in files:
        totalFiles += 1

print('Total number of test images',totalFiles)
print('Total Number of classes',totalDir)
# Out:
# Searching in :  dogImages/test/
# Searching in :  dogImages/test/027.Bloodhound
# Searching in :  dogImages/test/072.German_shorthaired_pointer
# Searching in :  dogImages/test/047.Chesapeake_bay_retriever
# Searching in :  dogImages/test/102.Manchester_terrier
# Searching in :  dogImages/test/070.German_pinscher
# Searching in :  dogImages/test/094.Komondor
# Searching in :  dogImages/test/025.Black_and_tan_coonhound
# Searching in :  dogImages/test/062.English_setter
# Searching in :  dogImages/test/035.Boykin_spaniel
# Searching in :  dogImages/test/087.Irish_terrier
# Searching in :  dogImages/test/024.Bichon_frise
# Searching in :  dogImages/test/017.Bearded_collie
# Searching in :  dogImages/test/112.Nova_scotia_duck_tolling_retriever
# Searching in :  dogImages/test/122.Pointer
# Searching in :  dogImages/test/018.Beauceron
# Searching in :  dogImages/test/085.Irish_red_and_white_setter
# Searching in :  dogImages/test/021.Belgian_sheepdog
# ...

# %%
#Number of validation images
import os
folders_path = 'dogImages/valid/'
totalFiles = 0
totalDir = 0
for base, dirs, files in os.walk(folders_path):
    print('Searching in : ',base)
    for directories in dirs:
        totalDir += 1
    for Files in files:
        totalFiles += 1

print('Total number of validation images',totalFiles)
print('Total Number of classes',totalDir)
# Out:
# Searching in :  dogImages/valid/
# Searching in :  dogImages/valid/027.Bloodhound
# Searching in :  dogImages/valid/072.German_shorthaired_pointer
# Searching in :  dogImages/valid/047.Chesapeake_bay_retriever
# Searching in :  dogImages/valid/102.Manchester_terrier
# Searching in :  dogImages/valid/070.German_pinscher
# Searching in :  dogImages/valid/094.Komondor
# Searching in :  dogImages/valid/025.Black_and_tan_coonhound
# Searching in :  dogImages/valid/062.English_setter
# Searching in :  dogImages/valid/035.Boykin_spaniel
# Searching in :  dogImages/valid/087.Irish_terrier
# Searching in :  dogImages/valid/024.Bichon_frise
# Searching in :  dogImages/valid/017.Bearded_collie
# Searching in :  dogImages/valid/112.Nova_scotia_duck_tolling_retriever
# Searching in :  dogImages/valid/122.Pointer
# Searching in :  dogImages/valid/018.Beauceron
# Searching in :  dogImages/valid/085.Irish_red_and_white_setter
# Searching in :  dogImages/valid/021.Belgian_sheepdog
# ...

# %%
import os
folders_path = 'dogImages'
totalFiles = 0
totalDir = 0
for base, dirs, files in os.walk(folders_path):
    print('Searching in : ',base)
    for directories in dirs:
        totalDir += 1
    for Files in files:
        totalFiles += 1

print('Total number of files',totalFiles)
print('Total Number of directories',totalDir)
# Out:
# Searching in :  dogImages
# Searching in :  dogImages/train
# Searching in :  dogImages/train/027.Bloodhound
# Searching in :  dogImages/train/072.German_shorthaired_pointer
# Searching in :  dogImages/train/047.Chesapeake_bay_retriever
# Searching in :  dogImages/train/102.Manchester_terrier
# Searching in :  dogImages/train/070.German_pinscher
# Searching in :  dogImages/train/094.Komondor
# Searching in :  dogImages/train/025.Black_and_tan_coonhound
# Searching in :  dogImages/train/062.English_setter
# Searching in :  dogImages/train/035.Boykin_spaniel
# Searching in :  dogImages/train/087.Irish_terrier
# Searching in :  dogImages/train/024.Bichon_frise
# Searching in :  dogImages/train/017.Bearded_collie
# Searching in :  dogImages/train/112.Nova_scotia_duck_tolling_retriever
# Searching in :  dogImages/train/122.Pointer
# Searching in :  dogImages/train/018.Beauceron
# Searching in :  dogImages/train/085.Irish_red_and_white_setter
# ...

# %%
# !pip install torchvision
# Out:
# ...
#      |████████████████████████████████| 23.3 MB 4.4 MB/s
# ...
#      |████████████████████████████████| 881.9 MB 3.4 kB/s             ��████████████████▍      | 698.2 MB 46.1 MB/s eta 0:00:04 MB 74.6 MB/s eta 0:00:01
# ...

# %% [markdown]
# ## Dataset
# TODO: Explain what dataset you are using for this project. Maybe even give a small overview of the classes, class distributions etc that can help anyone not familiar with the dataset get a better understand of it.

# %%
#TODO: Fetch and upload the data to AWS S3

# Command to download and unzip data
# !wget https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/dogImages.zip
# !unzip dogImages.zip
# Out:
# --2022-02-04 05:18:48--  https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/dogImages.zip
# Resolving s3-us-west-1.amazonaws.com (s3-us-west-1.amazonaws.com)... 52.219.120.192
# Connecting to s3-us-west-1.amazonaws.com (s3-us-west-1.amazonaws.com)|52.219.120.192|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1132023110 (1.1G) [application/zip]
# Saving to: ‘dogImages.zip’
#
# dogImages.zip       100%[===================>]   1.05G  6.23MB/s    in 2m 9s
#
# 2022-02-04 05:20:58 (8.34 MB/s) - ‘dogImages.zip’ saved [1132023110/1132023110]
#
# Archive:  dogImages.zip
#    creating: dogImages/
#    creating: dogImages/test/
#    creating: dogImages/train/
#    creating: dogImages/valid/
#    creating: dogImages/test/001.Affenpinscher/
#   inflating: dogImages/test/001.Affenpinscher/Affenpinscher_00003.jpg
#   inflating: dogImages/test/001.Affenpinscher/Affenpinscher_00023.jpg
#   inflating: dogImages/test/001.Affenpinscher/Affenpinscher_00036.jpg
# ...

# %% [markdown]
# ## Hyperparameter Tuning
# **TODO:** This is the part where you will finetune a pretrained model with hyperparameter tuning. Remember that you have to tune a minimum of two hyperparameters. However you are encouraged to tune more. You are also encouraged to explain why you chose to tune those particular hyperparameters and the ranges.
#
# **Note:** You will need to use the `hpo.py` script to perform hyperparameter tuning.

# %%
#TODO: Declare your HP ranges, metrics etc.
import sagemaker

from sagemaker.tuner import (
    IntegerParameter,
    CategoricalParameter,
    ContinuousParameter,
    HyperparameterTuner,
)

hyperparameter_ranges = {
    "lr": ContinuousParameter(0.001, 0.1),
    #batch-size": CategoricalParameter([256,512]),
    "batch-size": CategoricalParameter([32, 64, 128, 256, 512]),
    "epochs": IntegerParameter(4,10)
}


objective_metric_name = "average test loss"
objective_type = "Minimize"
metric_definitions = [{"Name": "average test loss", "Regex": "Test set: Average loss: ([0-9\\.]+)"}]

# %%
sagemaker_session = sagemaker.Session()

bucket = 'sagemaker-studio-g0o8pxe34gt'
prefix = 'Dog-Breed-Classification'

role = sagemaker.get_execution_role()

# %%
#TODO: Create estimators for your HPs

from sagemaker.pytorch import PyTorch

estimator = PyTorch(
    entry_point="hpo.py",
    role=role,
    py_version='py36',
    framework_version="1.8",
    instance_count=1,
    instance_type="ml.g4dn.xlarge"
)


tuner = HyperparameterTuner(
    estimator,
    objective_metric_name,
    hyperparameter_ranges,
    metric_definitions,
    max_jobs=4,
    max_parallel_jobs=2,
    objective_type=objective_type,
)

# %%
# TODO: Fit your HP Tuner
# TODO: Remember to include your data channels
#os.environ['SM_CHANNEL_TRAIN'] = 's3://sagemaker-studio-g0o8pxe34gt/dogImages/train'
#os.environ['SM_CHANNEL_TEST'] = 's3://sagemaker-studio-g0o8pxe34gt/dogImages/test'
#os.environ['SM_CHANNEL_VALID'] = 's3://sagemaker-studio-g0o8pxe34gt/dogImages/valid'

inputs = {'train' :  's3://sagemaker-studio-g0o8pxe34gt/dogImages/train',
           'test'  :  's3://sagemaker-studio-g0o8pxe34gt/dogImages/test',
           'valid' :  's3://sagemaker-studio-g0o8pxe34gt/dogImages/valid'
         
         }
        

tuner.fit(inputs, job_name = "DogImages-ClassificationJ1",wait= True)
# Out:
# .........................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................!

# %%
# TODO: Get the best estimators and the best HPs

best_estimator = tuner.best_estimator()#TODO

#Get the hyperparameters of the best trained model
best_estimator.hyperparameters()
# Out:
# 2022-02-09 10:02:00 Starting - Preparing the instances for training
# 2022-02-09 10:02:00 Downloading - Downloading input data
# 2022-02-09 10:02:00 Training - Training image download completed. Training in progress.
# 2022-02-09 10:02:00 Uploading - Uploading generated training model
# 2022-02-09 10:02:00 Completed - Training job completed
# {'_tuning_objective_metric': '"average test loss"',
#  'batch-size': '"64"',
#  'epochs': '9',
#  'lr': '0.015429772656044496',
#  'sagemaker_container_log_level': '20',
#  'sagemaker_estimator_class_name': '"PyTorch"',
#  'sagemaker_estimator_module': '"sagemaker.pytorch.estimator"',
#  'sagemaker_job_name': '"DogImages-ClassificationJ1"',
#  'sagemaker_program': '"hpo.py"',
#  'sagemaker_region': '"us-east-2"',
#  'sagemaker_submit_directory': '"s3://sagemaker-us-east-2-461971093615/DogImages-ClassificationJ1/source/sourcedir.tar.gz"'}

# %%
tuner.best_training_job()
# Out:
# 'DogImages-ClassificationJ1-002-9685a2cf'

# %% [markdown]
# ## Model Profiling and Debugging
# TODO: Using the best hyperparameters, create and finetune a new model
#
# **Note:** You will need to use the `train_model.py` script to perform model profiling and debugging.

# %%
# TODO: Set up debugging and profiling rules and hooks
# TODO: Set up debugging and profiling rules and hooks
import sagemaker
from sagemaker.debugger import Rule, ProfilerRule, rule_configs


rules = [ 
    Rule.sagemaker(rule_configs.loss_not_decreasing()),
    ProfilerRule.sagemaker(rule_configs.LowGPUUtilization()),
    ProfilerRule.sagemaker(rule_configs.ProfilerReport()),
    Rule.sagemaker(rule_configs.vanishing_gradient()),
    Rule.sagemaker(rule_configs.overfit()),
    Rule.sagemaker(rule_configs.overtraining()),
    Rule.sagemaker(rule_configs.poor_weight_initialization()),
    
]

# %%
from sagemaker.debugger import DebuggerHookConfig, ProfilerConfig, FrameworkProfile

profiler_config = ProfilerConfig(
    system_monitor_interval_millis = 500,
    framework_profile_params = FrameworkProfile(num_steps=10)
    
)
debugger_config =  DebuggerHookConfig(
    hook_parameters = {"train.save.onterval": "100", 
                       "eval.save_interval":"10"}
)

# %%
hyperparameters = {
    "batchsize": 64,
    "gpu": True,
    "epoch": 9,
    #"model": "resnet50",
    "lr" : "0.015429772656044496"
}

# %%
inputs1 = {'train' :  's3://sagemaker-studio-g0o8pxe34gt/dogImages/train',
           'test'  :  's3://sagemaker-studio-g0o8pxe34gt/dogImages/test',
           'valid' :  's3://sagemaker-studio-g0o8pxe34gt/dogImages/valid'
         
         }

# %%
# TODO: Create and fit an estimator
from sagemaker.pytorch import PyTorch
estimator = PyTorch(
    role = sagemaker.get_execution_role(),
    instance_count =1,
    instance_type = "ml.g4dn.xlarge",
    entry_point = "train_model.py",
    framework_version = "1.8",
    py_version = "py36",
    hyperparameters = hyperparameters,
    profiler_config = profiler_config,
    rules = rules
)

estimator.fit(inputs1,wait=True)
# Out:
# 2022-02-16 14:59:34 Starting - Starting the training job...
# 2022-02-16 14:59:50 Starting - Preparing the instances for trainingLossNotDecreasing: InProgress
# VanishingGradient: InProgress
# Overfit: InProgress
# Overtraining: InProgress
# PoorWeightInitialization: InProgress
# LowGPUUtilization: InProgress
# ProfilerReport: InProgress
# ......
# 2022-02-16 15:01:03 Downloading - Downloading input data.........
# 2022-02-16 15:02:32 Training - Downloading the training image....................bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
# 2022-02-16 15:05:41,143 sagemaker-training-toolkit INFO     Imported framework sagemaker_pytorch_container.training
# 2022-02-16 15:05:41,164 sagemaker_pytorch_container.training INFO     Block until all host DNS lookups succeed.
# 2022-02-16 15:05:41,172 sagemaker_pytorch_container.training INFO     Invoking user training script.
# ...

# %%
# TODO: Plot a debugging output.
from smdebug.trials import create_trial
from smdebug.core.modes import ModeKeys

trial = create_trial(estimator.latest_job_debugger_artifacts_path())
# Out:
# [2022-02-16 15:28:34.536 ip-172-16-50-81:15798 INFO s3_trial.py:42] Loading trial debug-output at path s3://sagemaker-us-east-2-461971093615/pytorch-training-2022-02-16-14-59-34-153/debug-output

# %%
trial.tensor_names()
# Out:
# [2022-02-16 15:28:36.266 ip-172-16-50-81:15798 INFO trial.py:198] Training has ended, will refresh one final time in 1 sec.
# [2022-02-16 15:28:37.296 ip-172-16-50-81:15798 INFO trial.py:210] Loaded all steps
# ['CrossEntropyLoss_output_0',
#  'gradient/ResNet_fc.0.bias',
#  'gradient/ResNet_fc.0.weight',
#  'layer1.0.relu_input_0',
#  'layer1.0.relu_input_1',
#  'layer1.1.relu_input_0',
#  'layer1.1.relu_input_1',
#  'layer2.0.relu_input_0',
#  'layer2.0.relu_input_1',
#  'layer2.1.relu_input_0',
#  'layer2.1.relu_input_1',
#  'layer3.0.relu_input_0',
#  'layer3.0.relu_input_1',
#  'layer3.1.relu_input_0',
#  'layer3.1.relu_input_1',
#  'layer4.0.relu_input_0',
#  'layer4.0.relu_input_1',
#  'layer4.1.relu_input_0',
#  'layer4.1.relu_input_1',
#  'relu_input_0']

# %%
len(trial.tensor("CrossEntropyLoss_output_0").steps(mode=ModeKeys.TRAIN))
# Out:
# 2

# %%
len(trial.tensor("CrossEntropyLoss_output_0").steps(mode=ModeKeys.EVAL))
# Out:
# 1

# %%
def get_data(trial, tname, mode):
    tensor = trial.tensor(tname)
    steps = tensor.steps(mode=mode)
    vals = []
    for s in steps:
        vals.append(tensor.value(s, mode=mode))
    return steps, vals

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import host_subplot


def plot_tensor(trial, tensor_name):

    steps_train, vals_train = get_data(trial, tensor_name, mode=ModeKeys.TRAIN)
    print("loaded TRAIN data")
    steps_eval, vals_eval = get_data(trial, tensor_name, mode=ModeKeys.EVAL)
    print("loaded EVAL data")

    fig = plt.figure(figsize=(10, 7))
    host = host_subplot(111)

    par = host.twiny()

    host.set_xlabel("Steps (TRAIN)")
    par.set_xlabel("Steps (EVAL)")
    host.set_ylabel(tensor_name)

    (p1,) = host.plot(steps_train, vals_train, label=tensor_name)
    print("completed TRAIN plot")
    (p2,) = par.plot(steps_eval, vals_eval, label="val_" + tensor_name)
    print("completed EVAL plot")
    leg = plt.legend()

    host.xaxis.get_label().set_color(p1.get_color())
    leg.texts[0].set_color(p1.get_color())

    par.xaxis.get_label().set_color(p2.get_color())
    leg.texts[1].set_color(p2.get_color())

    plt.ylabel(tensor_name)

    plt.show()

# %%
plot_tensor(trial, "CrossEntropyLoss_output_0")
# Out:
# loaded TRAIN data
# loaded EVAL data
# completed TRAIN plot
# completed EVAL plot

# %% [markdown]
# **TODO**: Is there some anomalous behaviour in your debugging output? If so, what is the error and how will you fix it?
# **TODO**: If not, suppose there was an error. What would that error look like and how would you have fixed it?

# %%
# TODO: Display the profiler output
rule_output_path = estimator.output_path + estimator.latest_training_job.job_name + "/rule-output"

# %%
from smdebug.profiler.analysis.notebook_utils.training_job import TrainingJob

tj = TrainingJob( estimator.latest_training_job.name, region)
tj.wait_for_sys_profiling_data_to_be_available()
# Out:
# ProfilerConfig:{'S3OutputPath': 's3://sagemaker-us-east-2-461971093615/', 'ProfilingIntervalInMilliseconds': 500, 'ProfilingParameters': {'DataloaderProfilingConfig': '{"StartStep": 0, "NumSteps": 10, "MetricsRegex": ".*", }', 'DetailedProfilingConfig': '{"StartStep": 0, "NumSteps": 10, }', 'FileOpenFailThreshold': '50', 'HorovodProfilingConfig': '{"StartStep": 0, "NumSteps": 10, }', 'LocalPath': '/opt/ml/output/profiler', 'PythonProfilingConfig': '{"StartStep": 0, "NumSteps": 10, "ProfilerName": "cprofile", "cProfileTimer": "total_time", }', 'RotateFileCloseIntervalInSeconds': '60', 'RotateMaxFileSizeInBytes': '10485760', 'SMDataParallelProfilingConfig': '{"StartStep": 0, "NumSteps": 10, }'}}
# s3 path:s3://sagemaker-us-east-2-461971093615/pytorch-training-2022-02-16-14-59-34-153/profiler-output
#
#
# Profiler data from system is available

# %%
from smdebug.profiler.analysis.notebook_utils.timeline_charts import TimelineCharts

system_metrics_reader = tj.get_systems_metrics_reader()
system_metrics_reader.refresh_event_file_list()

view_timeline_charts = TimelineCharts(
    system_metrics_reader,
    framework_metrics_reader=None,
    select_dimensions=["CPU", "GPU"],
    select_events=["total"],
)
# Out:
# [2022-02-16 15:29:08.625 ip-172-16-50-81:15798 INFO metrics_reader_base.py:134] Getting 23 event files
# select events:['total']
# select dimensions:['CPU', 'GPU']
# filtered_events:{'total'}
# filtered_dimensions:{'CPUUtilization-nodeid:algo-1', 'GPUUtilization-nodeid:algo-1', 'GPUMemoryUtilization-nodeid:algo-1'}
#   <div class="bk-root" id="b6a8a013-3cd8-4f26-bdc3-55e769e214cc" data-root-id="1448"></div>

# %%
! aws s3 ls {rule_output_path} --recursive
# Out:
# 2022-02-16 15:24:05     417245 pytorch-training-2022-02-16-14-59-34-153/rule-output/ProfilerReport/profiler-output/profiler-report.html
# 2022-02-16 15:24:04     272423 pytorch-training-2022-02-16-14-59-34-153/rule-output/ProfilerReport/profiler-output/profiler-report.ipynb
# 2022-02-16 15:23:59        192 pytorch-training-2022-02-16-14-59-34-153/rule-output/ProfilerReport/profiler-output/profiler-reports/BatchSize.json
# 2022-02-16 15:24:00      60950 pytorch-training-2022-02-16-14-59-34-153/rule-output/ProfilerReport/profiler-output/profiler-reports/CPUBottleneck.json
# 2022-02-16 15:24:00       1969 pytorch-training-2022-02-16-14-59-34-153/rule-output/ProfilerReport/profiler-output/profiler-reports/Dataloader.json
# 2022-02-16 15:24:00        130 pytorch-training-2022-02-16-14-59-34-153/rule-output/ProfilerReport/profiler-output/profiler-reports/GPUMemoryIncrease.json
# ...

# %%
! aws s3 cp {rule_output_path} ./ --recursive
# Out:
# download: s3://sagemaker-us-east-2-461971093615/pytorch-training-2022-02-16-13-18-30-921/rule-output/ProfilerReport/profiler-output/profiler-reports/CPUBottleneck.json to ProfilerReport/profiler-output/profiler-reports/CPUBottleneck.json
# download: s3://sagemaker-us-east-2-461971093615/pytorch-training-2022-02-16-13-18-30-921/rule-output/ProfilerReport/profiler-output/profiler-reports/IOBottleneck.json to ProfilerReport/profiler-output/profiler-reports/IOBottleneck.json
# download: s3://sagemaker-us-east-2-461971093615/pytorch-training-2022-02-16-13-18-30-921/rule-output/ProfilerReport/profiler-output/profiler-reports/LoadBalancing.json to ProfilerReport/profiler-output/profiler-reports/LoadBalancing.json
# download: s3://sagemaker-us-east-2-461971093615/pytorch-training-2022-02-16-13-18-30-921/rule-output/ProfilerReport/profiler-output/profiler-report.html to ProfilerReport/profiler-output/profiler-report.html
# ...

# %%
import os

# get the autogenerated folder name of profiler report
profiler_report_name = [
    rule["RuleConfigurationName"]
    for rule in estimator.latest_training_job.rule_job_summary()
    if "Profiler" in rule["RuleConfigurationName"]
][0]

# %%
import IPython

IPython.display.HTML(filename=profiler_report_name + "/profiler-output/profiler-report.html")
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    profiler-report
#   </title>
#   <script src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.1.10/require.min.js">
#   </script>
#   <script src="https://cdnjs.cloudflare.com/ajax/libs/jquery/2.0.3/jquery.min.js">
#   </script>
#   <style type="text/css">
#    /*!
# *
# * Twitter Bootstrap
# *
# */
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
#  */
# /*! normalize.css v3.0.3 | MIT License | github.com/necolas/normalize.css */
# html {
#   font-family: sans-serif;
#   -ms-text-size-adjust: 100%;
#   -webkit-text-size-adjust: 100%;
# }
# body {
#   margin: 0;
# }
# article,
# aside,
# details,
# figcaption,
# figure,
# footer,
# header,
# hgroup,
# main,
# menu,
# nav,
# section,
# summary {
#   display: block;
# }
# audio,
# canvas,
# progress,
# video {
# ...

# %% [markdown]
# ## Model Deploying

# %%
# TODO: Deploy your model to an endpoint

predictor=estimator.deploy(
    initial_instance_count=1,
    instance_type='ml.m5.xlarge'

) # TODO: Add your deployment configuration like instance type and number of instances

#Dogbreed-endpoint = predictor.endpoint_name
# Out:
# -----!

# %%
# TODO: Your code to load and preprocess image to send to endpoint for prediction
from sagemaker.serializers import IdentitySerializer
import base64

predictor.serializer = IdentitySerializer("image/png")
with open("dogImages/test/002.Afghan_hound/Afghan_hound_00116.jpg", "rb") as f:
    payload = f.read()

# %%
from PIL import Image
import io
Image.open(io.BytesIO(payload))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=484x500 at 0x7FB045B74F28>

# %%
response=predictor.predict(payload, initial_args={"ContentType": "image/jpeg"})
# Out:
# ---------------------------------------------------------------------------
# ModelError                                Traceback (most recent call last)
# <ipython-input-120-00b5bab3fcb0> in <module>
# ----> 1 response=predictor.predict(payload, initial_args={"ContentType": "image/jpeg"})
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/sagemaker/predictor.py in predict(self, data, initial_args, target_model, target_variant, inference_id)
#     159             data, initial_args, target_model, target_variant, inference_id
#     160         )
# --> 161         response = self.sagemaker_session.sagemaker_runtime_client.invoke_endpoint(**request_args)
#     162         return self._handle_response(response)
#     163
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/botocore/client.py in _api_call(self, *args, **kwargs)
#     389                     "%s() only accepts keyword arguments." % py_operation_name)
# ...

# %%
# TODO: Run an prediction on the endpoint
import numpy as np


np.argmax(response, 1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-121-7e4d43fce460> in <module>
#       3
#       4
# ----> 5 np.argmax(response, 1)
#
# NameError: name 'response' is not defined

# %%
# TODO: Remember to shutdown/delete your endpoint once your work is done
predictor.delete_endpoint()
